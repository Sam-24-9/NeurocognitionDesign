# %%
# Import required libraries
import pandas as pd
from scipy.stats import pearsonr

# Load the dataset
file_path = "Alpha-review.xlsx"
df = pd.read_excel(file_path, sheet_name="Sheet1")

# Compute brain region averages
df["F_Left"] = df[["Fp1", "F7", "F3", "FC1"]].mean(axis=1, skipna=True)
df["F_Right"] = df[["Fp2", "F8", "F4", "FC2"]].mean(axis=1, skipna=True)
df["F"] = df[["F_Left", "F_Right"]].mean(axis=1, skipna=True)

df["C_Left"] = df[["FC5", "C3"]].mean(axis=1, skipna=True)
df["C_Right"] = df[["FC6", "C4"]].mean(axis=1, skipna=True)
df["C"] = df[["C_Left", "C_Right"]].mean(axis=1, skipna=True)

df["T_Left"] = df[["FT9", "T7", "CP5", "TP9"]].mean(axis=1, skipna=True)
df["T_Right"] = df[["FT10", "T8", "CP6", "TP10"]].mean(axis=1, skipna=True)
df["T"] = df[["T_Left", "T_Right"]].mean(axis=1, skipna=True)

df["P_Left"] = df[["CP1", "P3"]].mean(axis=1, skipna=True)
df["P_Right"] = df[["CP2", "P4"]].mean(axis=1, skipna=True)
df["P"] = df[["P_Left", "P_Right"]].mean(axis=1, skipna=True)

df["O_Left"] = df[["O1", "P7"]].mean(axis=1, skipna=True)
df["O_Right"] = df[["O2", "P8"]].mean(axis=1, skipna=True)
df["O"] = df[["O_Left", "O_Right"]].mean(axis=1, skipna=True)

df["H_Right"] = df[["O_Right", "F_Right", "C_Right", "T_Right", "P_Right"]].mean(axis=1, skipna=True)
df["H_Left"] = df[["O_Left", "F_Left", "C_Left", "T_Left", "P_Left"]].mean(axis=1, skipna=True)

# Correlation analysis
targets = ["RT", "Word counts", "Stress"]
regions = ["F", "F_Left", "F_Right", "C", "C_Left", "C_Right", "T", "T_Left", "T_Right", "P", "P_Left", "P_Right", "O", "O_Left", "O_Right", "H_Right", "H_Left"]

# Compute and print Pearson correlation for each combination
for region in regions:
    for target in targets:
        clean_data = df[[region, target]].dropna()
        if not clean_data.empty:
            corr, pval = pearsonr(clean_data[region], clean_data[target])
            print(f"Correlation between {region} and {target}: r = {corr:.3f}, p = {pval:.3g}")
        else:
            print(f"Insufficient data for correlation between {region} and {target}")
# Out:
# Correlation between F and RT: r = -0.011, p = 0.707
# Correlation between F and Word counts: r = -0.030, p = 0.306
# Correlation between F and Stress: r = -0.140, p = 2.11e-06
# Correlation between F_Left and RT: r = -0.004, p = 0.899
# Correlation between F_Left and Word counts: r = -0.020, p = 0.491
# Correlation between F_Left and Stress: r = -0.144, p = 1.11e-06
# Correlation between F_Right and RT: r = -0.018, p = 0.552
# Correlation between F_Right and Word counts: r = -0.038, p = 0.199
# Correlation between F_Right and Stress: r = -0.128, p = 1.46e-05
# Correlation between C and RT: r = 0.005, p = 0.868
# Correlation between C and Word counts: r = -0.015, p = 0.605
# Correlation between C and Stress: r = -0.148, p = 5.22e-07
# Correlation between C_Left and RT: r = 0.016, p = 0.593
# Correlation between C_Left and Word counts: r = 0.005, p = 0.877
# Correlation between C_Left and Stress: r = -0.150, p = 3.6e-07
# Correlation between C_Right and RT: r = -0.006, p = 0.83
# Correlation between C_Right and Word counts: r = -0.032, p = 0.279
# Correlation between C_Right and Stress: r = -0.123, p = 3.18e-05
# Correlation between T and RT: r = -0.019, p = 0.523
# Correlation between T and Word counts: r = -0.027, p = 0.353
# Correlation between T and Stress: r = -0.134, p = 5.95e-06
# Correlation between T_Left and RT: r = 0.005, p = 0.86
# Correlation between T_Left and Word counts: r = -0.010, p = 0.731
# Correlation between T_Left and Stress: r = -0.145, p = 9.18e-07
# Correlation between T_Right and RT: r = -0.038, p = 0.196
# Correlation between T_Right and Word counts: r = -0.039, p = 0.186
# Correlation between T_Right and Stress: r = -0.102, p = 0.000592
# Correlation between P and RT: r = 0.029, p = 0.324
# Correlation between P and Word counts: r = 0.017, p = 0.576
# Correlation between P and Stress: r = -0.116, p = 8.9e-05
# Correlation between P_Left and RT: r = 0.040, p = 0.171
# Correlation between P_Left and Word counts: r = 0.025, p = 0.401
# Correlation between P_Left and Stress: r = -0.121, p = 4.01e-05
# Correlation between P_Right and RT: r = 0.016, p = 0.595
# Correlation between P_Right and Word counts: r = 0.007, p = 0.811
# Correlation between P_Right and Stress: r = -0.101, p = 0.000649
# Correlation between O and RT: r = 0.004, p = 0.905
# Correlation between O and Word counts: r = 0.019, p = 0.528
# Correlation between O and Stress: r = -0.109, p = 0.000223
# Correlation between O_Left and RT: r = 0.028, p = 0.352
# Correlation between O_Left and Word counts: r = 0.032, p = 0.278
# Correlation between O_Left and Stress: r = -0.117, p = 7.82e-05
# Correlation between O_Right and RT: r = -0.022, p = 0.467
# Correlation between O_Right and Word counts: r = 0.003, p = 0.932
# Correlation between O_Right and Stress: r = -0.088, p = 0.00305
# Correlation between H_Right and RT: r = -0.014, p = 0.627
# Correlation between H_Right and Word counts: r = -0.021, p = 0.487
# Correlation between H_Right and Stress: r = -0.118, p = 6.71e-05
# Correlation between H_Left and RT: r = 0.020, p = 0.493
# Correlation between H_Left and Word counts: r = 0.009, p = 0.767
# Correlation between H_Left and Stress: r = -0.148, p = 5.12e-07

# %%
import pandas as pd
from scipy.stats import pearsonr

# Load the dataset
file_pathb = "Beta-review.xlsx"
dfb = pd.read_excel(file_pathb, sheet_name="Sheet1")

# Clean problematic numeric columns (e.g., values like '30+3')
for col in ["RT", "NW", "Stress"]:
    dfb[col] = pd.to_numeric(dfb[col], errors='coerce')

# Compute brain region averages
dfb["F_Left"] = dfb[["Fp1", "F7", "F3", "FC1"]].mean(axis=1, skipna=True)
dfb["F_Right"] = dfb[["Fp2", "F8", "F4", "FC2"]].mean(axis=1, skipna=True)
dfb["F"] = dfb[["F_Left", "F_Right"]].mean(axis=1, skipna=True)

dfb["C_Left"] = dfb[["FC5", "C3"]].mean(axis=1, skipna=True)
dfb["C_Right"] = dfb[["FC6", "C4"]].mean(axis=1, skipna=True)
dfb["C"] = dfb[["C_Left", "C_Right"]].mean(axis=1, skipna=True)

dfb["T_Left"] = dfb[["FT9", "T7", "CP5", "TP9"]].mean(axis=1, skipna=True)
dfb["T_Right"] = dfb[["FT10", "T8", "CP6", "TP10"]].mean(axis=1, skipna=True)
dfb["T"] = dfb[["T_Left", "T_Right"]].mean(axis=1, skipna=True)

dfb["P_Left"] = dfb[["CP1", "P3"]].mean(axis=1, skipna=True)
dfb["P_Right"] = dfb[["CP2", "P4"]].mean(axis=1, skipna=True)
dfb["P"] = dfb[["P_Left", "P_Right"]].mean(axis=1, skipna=True)

dfb["O_Left"] = dfb[["O1", "P7"]].mean(axis=1, skipna=True)
dfb["O_Right"] = dfb[["O2", "P8"]].mean(axis=1, skipna=True)
dfb["O"] = dfb[["O_Left", "O_Right"]].mean(axis=1, skipna=True)

dfb["H_Right"] = dfb[["O_Right", "F_Right", "C_Right", "T_Right", "P_Right"]].mean(axis=1, skipna=True)
dfb["H_Left"] = dfb[["O_Left", "F_Left", "C_Left", "T_Left", "P_Left"]].mean(axis=1, skipna=True)

# Correlation analysis
targetsb = ["RT", "NW", "Stress"]
regionsb = ["F", "F_Left", "F_Right", "C", "C_Left", "C_Right", "T", "T_Left", "T_Right", "P", "P_Left", "P_Right", "O", "O_Left", "O_Right", "H_Right", "H_Left"]

# Compute and print Pearson correlation for each combination
for regionb in regionsb:
    for targetb in targetsb:
        clean_datab = dfb[[regionb, targetb]].dropna()
        if not clean_datab.empty:
            corr, pval = pearsonr(clean_datab[regionb], clean_datab[targetb])
            print(f"Correlation between {regionb} and {targetb}: r = {corr:.3f}, p = {pval:.3g}")
        else:
            print(f"Insufficient data for correlation between {regionb} and {targetb}")
# Out:
# Correlation between F and RT: r = -0.143, p = 9.14e-07
# Correlation between F and NW: r = -0.082, p = 0.00469
# Correlation between F and Stress: r = -0.112, p = 0.000125
# Correlation between F_Left and RT: r = -0.130, p = 7.76e-06
# Correlation between F_Left and NW: r = -0.076, p = 0.00866
# Correlation between F_Left and Stress: r = -0.110, p = 0.000149
# Correlation between F_Right and RT: r = -0.150, p = 2.51e-07
# Correlation between F_Right and NW: r = -0.085, p = 0.00349
# Correlation between F_Right and Stress: r = -0.108, p = 0.000193
# Correlation between C and RT: r = -0.117, p = 5.54e-05
# Correlation between C and NW: r = -0.050, p = 0.085
# Correlation between C and Stress: r = -0.133, p = 4.35e-06
# Correlation between C_Left and RT: r = -0.092, p = 0.00152
# Correlation between C_Left and NW: r = -0.035, p = 0.231
# Correlation between C_Left and Stress: r = -0.135, p = 3.42e-06
# Correlation between C_Right and RT: r = -0.130, p = 7.2e-06
# Correlation between C_Right and NW: r = -0.060, p = 0.0381
# Correlation between C_Right and Stress: r = -0.119, p = 4.55e-05
# Correlation between T and RT: r = -0.136, p = 2.73e-06
# Correlation between T and NW: r = -0.063, p = 0.0303
# Correlation between T and Stress: r = -0.152, p = 1.71e-07
# Correlation between T_Left and RT: r = -0.128, p = 1.14e-05
# Correlation between T_Left and NW: r = -0.062, p = 0.0336
# Correlation between T_Left and Stress: r = -0.154, p = 1.03e-07
# Correlation between T_Right and RT: r = -0.131, p = 6.82e-06
# Correlation between T_Right and NW: r = -0.058, p = 0.0477
# Correlation between T_Right and Stress: r = -0.133, p = 4.55e-06
# Correlation between P and RT: r = -0.079, p = 0.00651
# Correlation between P and NW: r = -0.032, p = 0.267
# Correlation between P and Stress: r = -0.134, p = 3.69e-06
# Correlation between P_Left and RT: r = -0.071, p = 0.0152
# Correlation between P_Left and NW: r = -0.033, p = 0.251
# Correlation between P_Left and Stress: r = -0.147, p = 3.72e-07
# Correlation between P_Right and RT: r = -0.083, p = 0.00436
# Correlation between P_Right and NW: r = -0.029, p = 0.316
# Correlation between P_Right and Stress: r = -0.113, p = 0.000102
# Correlation between O and RT: r = -0.154, p = 1.23e-07
# Correlation between O and NW: r = -0.051, p = 0.0803
# Correlation between O and Stress: r = -0.138, p = 2.04e-06
# Correlation between O_Left and RT: r = -0.134, p = 4.28e-06
# Correlation between O_Left and NW: r = -0.046, p = 0.116
# Correlation between O_Left and Stress: r = -0.147, p = 4.35e-07
# Correlation between O_Right and RT: r = -0.158, p = 5.03e-08
# Correlation between O_Right and NW: r = -0.051, p = 0.0797
# Correlation between O_Right and Stress: r = -0.115, p = 7.69e-05
# Correlation between H_Right and RT: r = -0.140, p = 1.5e-06
# Correlation between H_Right and NW: r = -0.061, p = 0.0379
# Correlation between H_Right and Stress: r = -0.127, p = 1.33e-05
# Correlation between H_Left and RT: r = -0.118, p = 5.16e-05
# Correlation between H_Left and NW: r = -0.053, p = 0.0668
# Correlation between H_Left and Stress: r = -0.148, p = 3.12e-07

# %%
import pandas as pd
from scipy.stats import pearsonr

# Load the dataset
file_pathb = "Gamma-review.xlsx"
dfb = pd.read_excel(file_pathb, sheet_name="Sheet1")

# Clean problematic numeric columns (e.g., values like '30+3')
for col in ["RT", "NW", "Stress"]:
    dfb[col] = pd.to_numeric(dfb[col], errors='coerce')

# Compute brain region averages
dfb["F_Left"] = dfb[["Fp1", "F7", "F3", "FC1"]].mean(axis=1, skipna=True)
dfb["F_Right"] = dfb[["Fp2", "F8", "F4", "FC2"]].mean(axis=1, skipna=True)
dfb["F"] = dfb[["F_Left", "F_Right"]].mean(axis=1, skipna=True)

dfb["C_Left"] = dfb[["FC5", "C3"]].mean(axis=1, skipna=True)
dfb["C_Right"] = dfb[["FC6", "C4"]].mean(axis=1, skipna=True)
dfb["C"] = dfb[["C_Left", "C_Right"]].mean(axis=1, skipna=True)

dfb["T_Left"] = dfb[["FT9", "T7", "CP5", "TP9"]].mean(axis=1, skipna=True)
dfb["T_Right"] = dfb[["FT10", "T8", "CP6", "TP10"]].mean(axis=1, skipna=True)
dfb["T"] = dfb[["T_Left", "T_Right"]].mean(axis=1, skipna=True)

dfb["P_Left"] = dfb[["CP1", "P3"]].mean(axis=1, skipna=True)
dfb["P_Right"] = dfb[["CP2", "P4"]].mean(axis=1, skipna=True)
dfb["P"] = dfb[["P_Left", "P_Right"]].mean(axis=1, skipna=True)

dfb["O_Left"] = dfb[["O1", "P7"]].mean(axis=1, skipna=True)
dfb["O_Right"] = dfb[["O2", "P8"]].mean(axis=1, skipna=True)
dfb["O"] = dfb[["O_Left", "O_Right"]].mean(axis=1, skipna=True)

dfb["H_Right"] = dfb[["O_Right", "F_Right", "C_Right", "T_Right", "P_Right"]].mean(axis=1, skipna=True)
dfb["H_Left"] = dfb[["O_Left", "F_Left", "C_Left", "T_Left", "P_Left"]].mean(axis=1, skipna=True)

# Correlation analysis
targetsb = ["RT", "NW", "Stress"]
regionsb = ["F", "F_Left", "F_Right", "C", "C_Left", "C_Right", "T", "T_Left", "T_Right", "P", "P_Left", "P_Right", "O", "O_Left", "O_Right", "H_Right", "H_Left"]

# Compute and print Pearson correlation for each combination
for regionb in regionsb:
    for targetb in targetsb:
        clean_datab = dfb[[regionb, targetb]].dropna()
        if not clean_datab.empty:
            corr, pval = pearsonr(clean_datab[regionb], clean_datab[targetb])
            print(f"Correlation between {regionb} and {targetb}: r = {corr:.3f}, p = {pval:.3g}")
        else:
            print(f"Insufficient data for correlation between {regionb} and {targetb}")
# Out:
# Correlation between F and RT: r = -0.228, p = 2.35e-15
# Correlation between F and NW: r = -0.100, p = 0.000562
# Correlation between F and Stress: r = -0.101, p = 0.000539
# Correlation between F_Left and RT: r = -0.218, p = 3.68e-14
# Correlation between F_Left and NW: r = -0.105, p = 0.000308
# Correlation between F_Left and Stress: r = -0.109, p = 0.000185
# Correlation between F_Right and RT: r = -0.232, p = 7.41e-16
# Correlation between F_Right and NW: r = -0.093, p = 0.00133
# Correlation between F_Right and Stress: r = -0.090, p = 0.0019
# Correlation between C and RT: r = -0.210, p = 3.3e-13
# Correlation between C and NW: r = -0.067, p = 0.0211
# Correlation between C and Stress: r = -0.091, p = 0.00175
# Correlation between C_Left and RT: r = -0.183, p = 2.63e-10
# Correlation between C_Left and NW: r = -0.062, p = 0.0347
# Correlation between C_Left and Stress: r = -0.087, p = 0.0027
# Correlation between C_Right and RT: r = -0.223, p = 9.32e-15
# Correlation between C_Right and NW: r = -0.068, p = 0.019
# Correlation between C_Right and Stress: r = -0.089, p = 0.00229
# Correlation between T and RT: r = -0.250, p = 3.22e-18
# Correlation between T and NW: r = -0.108, p = 0.000207
# Correlation between T and Stress: r = -0.115, p = 7.63e-05
# Correlation between T_Left and RT: r = -0.244, p = 2.13e-17
# Correlation between T_Left and NW: r = -0.105, p = 0.000313
# Correlation between T_Left and Stress: r = -0.104, p = 0.000339
# Correlation between T_Right and RT: r = -0.245, p = 1.73e-17
# Correlation between T_Right and NW: r = -0.106, p = 0.000266
# Correlation between T_Right and Stress: r = -0.121, p = 3.34e-05
# Correlation between P and RT: r = -0.225, p = 6.79e-15
# Correlation between P and NW: r = -0.107, p = 0.000234
# Correlation between P and Stress: r = -0.123, p = 2.15e-05
# Correlation between P_Left and RT: r = -0.214, p = 1.38e-13
# Correlation between P_Left and NW: r = -0.105, p = 0.00032
# Correlation between P_Left and Stress: r = -0.116, p = 7.05e-05
# Correlation between P_Right and RT: r = -0.229, p = 1.79e-15
# Correlation between P_Right and NW: r = -0.106, p = 0.000261
# Correlation between P_Right and Stress: r = -0.128, p = 1.06e-05
# Correlation between O and RT: r = -0.267, p = 1.44e-20
# Correlation between O and NW: r = -0.142, p = 1.07e-06
# Correlation between O and Stress: r = -0.126, p = 1.35e-05
# Correlation between O_Left and RT: r = -0.250, p = 3.19e-18
# Correlation between O_Left and NW: r = -0.137, p = 2.24e-06
# Correlation between O_Left and Stress: r = -0.114, p = 8.89e-05
# Correlation between O_Right and RT: r = -0.271, p = 3.25e-21
# Correlation between O_Right and NW: r = -0.139, p = 1.65e-06
# Correlation between O_Right and Stress: r = -0.134, p = 4.23e-06
# Correlation between H_Right and RT: r = -0.248, p = 6.5e-18
# Correlation between H_Right and NW: r = -0.105, p = 0.000307
# Correlation between H_Right and Stress: r = -0.115, p = 7.36e-05
# Correlation between H_Left and RT: r = -0.229, p = 1.87e-15
# Correlation between H_Left and NW: r = -0.106, p = 0.000284
# Correlation between H_Left and Stress: r = -0.109, p = 0.00017
